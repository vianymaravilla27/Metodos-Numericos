# %% [markdown]
# # TAREA 4.2 METODOS NUMÉRICOS - METODO DE NEWTON MULTIPLE
#
# ## Alumno:
# Maravilla Pérez Vianey
# ## Profesor:
# Israel Sánchez Mendoza
# ## Fecha de la clase:
# 2/Septiembre/2021
#
# ### Descripción de la tarea:
# Para las siguientes funciones considere la ecuacion algebraıca f(x) = 0, aplique
# el metodo de Newton para obtener una aproximacion para la cual se satisfaga el siguiente error:
#
# $$|f (xn)| + |xn − xn−1| ≤ 1 × 10^−15$$
#
# ### Procedimiento
# Para lo anterior, considere las siguientes funciones:
# 1. $f : R → R$ donde la funcion f esta dada por:
# $$f (x) = 1 − 4x cos (x) + 2x^2 + cos (2x)$$,
# considere el punto inicial x0 = 0.5.
#
# 2. $f : R → R$ donde la funcion f esta dada por:
# $$f(x) =x^2 + 6x^5 + 9x^4 − 2x^3 − 6x^2 + 1.$$,
# considere el punto inicial x0 = -3.
#
# 3. $f : R → R$ donde la funcion f esta dada por:
# $$f(x)= e^3x − 27x^6 + 27x^4e^x − 9x^2e^2x$$,
# considere el punto inicial x0 = 3.5.

# %% [markdown]
# ## 1.- Función $$f (x) = 1 − 4x cos (x) + 2x^2 + cos (2x)$$
# considere el punto inicial x0 = 0.5.

# %% [markdown]
# # Procedimiento Función 1

# %%
# Importamos las funciones necesarias que empleara la función objetivo
from numpy import cos, sin, exp

# Procedemos a definir e inicializar las condiciones de paro del método
tol = 1.*(10**(-15)) # Obtener un error relativo de 10^(-20)
maxItera = 100 # Realizar máximo 100 iteraciones

# %%
# Definimos la funcion objetivo
def fx(x):
    fx = 1 - (4*x)*(cos(x)) + 2*(x**2) + cos(2*x)
    return fx

# Definimos la primera derivada de la funcion objetivo
def fxp(x):
    fxp = -2*sin(2*x)+(4*x)*sin(x)-(4*cos(x))+4*x
    return fxp

# Definimos la segunda derivada de la funcion objetivo
def fxpp(x):
    fxpp = -4*cos(2*x)+8*sin(x)+(4*x)*cos(x)+4
    return fxpp

# %%
# Definimos el punto inicial donde comenzaremos por aplicar el método así como el indice de conteo de las
# iteraciones y un error grande a fin de inicializar el método
p0 = 0.35 # aproximación inicial
k = 0 # Inicilizamos las iteraciones
error = 10000 # Inicializamos el valor del error en un número muy grande
pAnterior = p0 # Inicializamos la primer aproximación como b

# %%
# Definimos una funcion que defina el método iterativo del punto fijo
def itenewtonmultiple(a, fx, fxp, fxpp):
    # Evaluamos para validar si ya tenemos la raíz
    evalua = fx(a)
    # Validamos si llegamos a las raíz
    if evalua==0:
        return 0, a
    else:
        return 1, a -((fx(a)*fxp(a))/(fxp(a)**2-fx(a)*fxpp(a)))

# %%
# Empezamos el método de newton con los datos dados

# En este caso ya tenemos la raíz deseada
if fx(p0) == 0:
    # Se describe que existe una raíz en el punto dado previamente
    print('Se ha encontrado la raíz de la ecuación, la cual está dado por el punto {0}.'.format(p0))
    
# Dado que no tenemos la raíz aún procedemos a realizar iteraciones
else:
    # Señalamos que iniciamos el proceso iterativo
    print('Iniciamos el proceso iterativo')
    
    # Iniciamos el proceso iterativo
    while (error > tol and k < maxItera):
        
        # Iteramos el proceso
        itera = itenewtonmultiple(p0, fx, fxp, fxpp)
        
        # Validamos los casos obtenidos de la bandera, si esta es 0, se ha determinado la raíz
        if itera[0] == 0:
            # Describimos que hemos determinado el punto fijo y lo imprimimos
            print('La raíz de la ecuación se encuentra en el punto: {0}.'.format(itera[1]))
            k = maxItera
            
        # Validamos los casos obtenidos de la bandera, si esta es 1, no se ha determinado el punto fijo
        else:
            # Incrementamos en 1 las iteraciones realizadas
            k = k + 1
            
            # Imprimimos los resultados obtenidos de la iteracion
            print('Resultados de la iteracion {0}.'.format(k))
            print('La aproximación de la raíz se encuentra dada por {:.8}.'.format(itera[1]))
            print('El valor de la función bajo la aproximación es {:.8}.'.format(fx(itera[1])))
            
            # Actualizamos las variables
            error = abs(p0 - itera[1]) + abs(fx(p0)) # Error de aproximaciones
            p0 = itera[1]
            
            # Imprimimos el error
            print('El error relativo se encuentra dado por {:.8}.\n'.format(error))
# Out:
# Iniciamos el proceso iterativo
# Resultados de la iteracion 1.
# La aproximación de la raíz se encuentra dada por 0.68579221.
# El valor de la función bajo la aproximación es 0.015532169.
# El error relativo se encuentra dado por 1.0305126.
#
# Resultados de la iteracion 2.
# La aproximación de la raíz se encuentra dada por 0.73840301.
# El valor de la función bajo la aproximación es 2.6057855e-06.
# El error relativo se encuentra dado por 0.068142968.
#
# Resultados de la iteracion 3.
# La aproximación de la raíz se encuentra dada por 0.73908503.
# El valor de la función bajo la aproximación es 5.953571e-14.
# El error relativo se encuentra dado por 0.00068462952.
#
# Resultados de la iteracion 4.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es 1.3877788e-17.
# El error relativo se encuentra dado por 1.0379965e-07.
#
# Resultados de la iteracion 5.
# La aproximación de la raíz se encuentra dada por 0.73908514.
# El valor de la función bajo la aproximación es 5.5511151e-17.
# El error relativo se encuentra dado por 3.3547917e-09.
#
# Resultados de la iteracion 6.
# La aproximación de la raíz se encuentra dada por 0.73908514.
# El valor de la función bajo la aproximación es 3.6082248e-16.
# El error relativo se encuentra dado por 1.5750692e-09.
#
# Resultados de la iteracion 7.
# La aproximación de la raíz se encuentra dada por 0.73908514.
# El valor de la función bajo la aproximación es 1.8041124e-16.
# El error relativo se encuentra dado por 3.5380016e-09.
#
# Resultados de la iteracion 8.
# La aproximación de la raíz se encuentra dada por 0.73908514.
# El valor de la función bajo la aproximación es 3.6082248e-16.
# El error relativo se encuentra dado por 4.364416e-09.
#
# Resultados de la iteracion 9.
# La aproximación de la raíz se encuentra dada por 0.73908514.
# El valor de la función bajo la aproximación es 1.3877788e-16.
# El error relativo se encuentra dado por 2.1354322e-09.
#
# Resultados de la iteracion 10.
# La aproximación de la raíz se encuentra dada por 0.73908512.
# El valor de la función bajo la aproximación es 2.6367797e-16.
# El error relativo se encuentra dado por 1.2896743e-08.
#
# Resultados de la iteracion 11.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es -1.110223e-16.
# El error relativo se encuentra dado por 3.7900539e-09.
#
# Resultados de la iteracion 12.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es 9.7144515e-17.
# El error relativo se encuentra dado por 1.4101287e-09.
#
# Resultados de la iteracion 13.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es 3.7470027e-16.
# El error relativo se encuentra dado por 1.6844562e-09.
#
# Resultados de la iteracion 14.
# La aproximación de la raíz se encuentra dada por 0.73908511.
# El valor de la función bajo la aproximación es 2.2343238e-15.
# El error relativo se encuentra dado por 1.543138e-08.
#
# Resultados de la iteracion 15.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es 4.7184479e-16.
# El error relativo se encuentra dado por 1.922276e-08.
#
# Resultados de la iteracion 16.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es -3.0531133e-16.
# El error relativo se encuentra dado por 1.0336715e-09.
#
# Resultados de la iteracion 17.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es 3.3306691e-16.
# El error relativo se encuentra dado por 1.7712421e-09.
#
# Resultados de la iteracion 18.
# La aproximación de la raíz se encuentra dada por 0.73908512.
# El valor de la función bajo la aproximación es 8.4654506e-16.
# El error relativo se encuentra dado por 7.4663582e-09.
#
# Resultados de la iteracion 19.
# La aproximación de la raíz se encuentra dada por 0.73908514.
# El valor de la función bajo la aproximación es 2.7755576e-16.
# El error relativo se encuentra dado por 1.649182e-08.
#
# Resultados de la iteracion 20.
# La aproximación de la raíz se encuentra dada por 0.73908508.
# El valor de la función bajo la aproximación es 1.3336554e-14.
# El error relativo se encuentra dado por 5.4016375e-08.
#
# Resultados de la iteracion 21.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es 3.469447e-16.
# El error relativo se encuentra dado por 4.8756007e-08.
#
# Resultados de la iteracion 22.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es -8.3266727e-17.
# El error relativo se encuentra dado por 4.8534191e-11.
#
# Resultados de la iteracion 23.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es -9.7144515e-17.
# El error relativo se encuentra dado por 9.6941205e-11.
#
# Resultados de la iteracion 24.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es -1.9428903e-16.
# El error relativo se encuentra dado por 1.9316669e-10.
#
# Resultados de la iteracion 25.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es 2.220446e-16.
# El error relativo se encuentra dado por 3.838537e-10.
#
# Resultados de la iteracion 26.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es 1.3877788e-17.
# El error relativo se encuentra dado por 7.948685e-10.
#
# Resultados de la iteracion 27.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es 1.2490009e-16.
# El error relativo se encuentra dado por 1.5985302e-09.
#
# Resultados de la iteracion 28.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es -4.1633363e-17.
# El error relativo se encuentra dado por 3.2639905e-11.
#
# Resultados de la iteracion 29.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es -1.5265567e-16.
# El error relativo se encuentra dado por 6.5201775e-11.
#
# Resultados de la iteracion 30.
# La aproximación de la raíz se encuentra dada por 0.73908513.
# El valor de la función bajo la aproximación es 0.0.
# El error relativo se encuentra dado por 1.3031547e-10.
#
# La raíz de la ecuación se encuentra en el punto: 0.7390851334759542.

# %% [markdown]
# ## 2.- Función $$f(x) =x^2 + 6x^5 + 9x^4 − 2x^3 − 6x^2 + 1.$$
# considere el punto inicial x0 = -3.

# %% [markdown]
# # Procedimiento Función 2

# %%
# Importamos las funciones necesarias que empleara la función objetivo
from numpy import cos, sin, exp

# Procedemos a definir e inicializar las condiciones de paro del método
tol = 1.*(10**(-15)) # Obtener un error relativo de 10^(-20)
maxItera = 27 # Realizar máximo 100 iteraciones

# %%
# Definimos la funcion objetivo
def fx(x):
    fx = x**2+6*x**5+9*x**4-2*x**3-6*x**2+1
    return fx

# Definimos la primera derivada de la funcion objetivo
def fxp(x):
    fxp = (2*x)*((15*x**3)+(18*x**2)-3*x-5)
    return fxp

# Definimos la segunda derivada de la funcion objetivo
def fxpp(x):
    fxpp = (120*x**3)+(108*x**2)-12*x-10
    return fxpp

# %%
# Definimos el punto inicial donde comenzaremos por aplicar el método así como el indice de conteo de las
# iteraciones y un error grande a fin de inicializar el método
p0 = .35 # aproximación inicial
k = 0 # Inicilizamos las iteraciones
error = 10000 # Inicializamos el valor del error en un número muy grande
pAnterior = p0 # Inicializamos la primer aproximación como b

# %%
# Definimos una funcion que defina el método iterativo del punto fijo
def itenewtonmultiple(a, fx, fxp, fxpp):
    # Evaluamos para validar si ya tenemos la raíz
    evalua = fx(a)
    # Validamos si llegamos a las raíz
    if evalua==0:
        return 0, a
    else:
        return 1, a -((fx(a)*fxp(a))/(fxp(a)**2-fx(a)*fxpp(a)))

# %%
# Empezamos el método de newton con los datos dados

# En este caso ya tenemos la raíz deseada
if fx(p0) == 0:
    # Se describe que existe una raíz en el punto dado previamente
    print('Se ha encontrado la raíz de la ecuación, la cual está dado por el punto {0}.'.format(p0))
    
# Dado que no tenemos la raíz aún procedemos a realizar iteraciones
else:
    # Señalamos que iniciamos el proceso iterativo
    print('Iniciamos el proceso iterativo')
    
    # Iniciamos el proceso iterativo
    while (error > tol and k < maxItera):
        
        # Iteramos el proceso
        itera = itenewtonmultiple(p0, fx, fxp, fxpp)
        
        # Validamos los casos obtenidos de la bandera, si esta es 0, se ha determinado la raíz
        if itera[0] == 0:
            # Describimos que hemos determinado el punto fijo y lo imprimimos
            print('La raíz de la ecuación se encuentra en el punto: {0}.'.format(itera[1]))
            k = maxItera
            
        # Validamos los casos obtenidos de la bandera, si esta es 1, no se ha determinado el punto fijo
        else:
            # Incrementamos en 1 las iteraciones realizadas
            k = k + 1
            
            # Imprimimos los resultados obtenidos de la iteracion
            print('Resultados de la iteracion {0}.'.format(k))
            print('La aproximación de la raíz se encuentra dada por {:.8}.'.format(itera[1]))
            print('El valor de la función bajo la aproximación es {:.8}.'.format(fx(itera[1])))
            
            # Actualizamos las variables
            error = abs(p0 - itera[1]) + abs(fx(p0)) # Error de aproximaciones
            p0 = itera[1]
            
            # Imprimimos el error
            print('El error relativo se encuentra dado por {:.8}.\n'.format(error))
# Out:
# Iniciamos el proceso iterativo
# Resultados de la iteracion 1.
# La aproximación de la raíz se encuentra dada por 0.69210075.
# El valor de la función bajo la aproximación es 0.95973568.
# El error relativo se encuentra dado por 0.81042013.
#
# Resultados de la iteracion 2.
# La aproximación de la raíz se encuentra dada por -0.084387029.
# El valor de la función bajo la aproximación es 0.96602674.
# El error relativo se encuentra dado por 1.7362235.
#
# Resultados de la iteracion 3.
# La aproximación de la raíz se encuentra dada por -0.17192846.
# El valor de la función bajo la aproximación es 0.8693297.
# El error relativo se encuentra dado por 1.0535682.
#
# Resultados de la iteracion 4.
# La aproximación de la raíz se encuentra dada por -0.35511907.
# El valor de la función bajo la aproximación es 0.56826655.
# El error relativo se encuentra dado por 1.0525203.
#
# Resultados de la iteracion 5.
# La aproximación de la raíz se encuentra dada por -1.0647099.
# El valor de la función bajo la aproximación es 1.1021467.
# El error relativo se encuentra dado por 1.2778574.
#
# Resultados de la iteracion 6.
# La aproximación de la raíz se encuentra dada por -1.0136705.
# El valor de la función bajo la aproximación es 1.0263497.
# El error relativo se encuentra dado por 1.1531861.
#
# Resultados de la iteracion 7.
# La aproximación de la raíz se encuentra dada por -0.89182466.
# El valor de la función bajo la aproximación es 0.75020192.
# El error relativo se encuentra dado por 1.1481956.
#
# Resultados de la iteracion 8.
# La aproximación de la raíz se encuentra dada por -0.5072217.
# El valor de la función bajo la aproximación es 0.36889149.
# El error relativo se encuentra dado por 1.1348049.
#
# Resultados de la iteracion 9.
# La aproximación de la raíz se encuentra dada por -0.37976692.
# El valor de la función bajo la aproximación es 0.52823438.
# El error relativo se encuentra dado por 0.49634627.
#
# Resultados de la iteracion 10.
# La aproximación de la raíz se encuentra dada por -1.7084176.
# El valor de la función bajo la aproximación es -14.273522.
# El error relativo se encuentra dado por 1.8568851.
#
# Resultados de la iteracion 11.
# La aproximación de la raíz se encuentra dada por -1.1178395.
# El valor de la función bajo la aproximación es 1.1260632.
# El error relativo se encuentra dado por 14.864101.
#
# Resultados de la iteracion 12.
# La aproximación de la raíz se encuentra dada por -1.1259661.
# El valor de la función bajo la aproximación es 1.1231446.
# El error relativo se encuentra dado por 1.1341898.
#
# Resultados de la iteracion 13.
# La aproximación de la raíz se encuentra dada por -1.1414895.
# El valor de la función bajo la aproximación es 1.1118108.
# El error relativo se encuentra dado por 1.138668.
#
# Resultados de la iteracion 14.
# La aproximación de la raíz se encuentra dada por -1.1697161.
# El valor de la función bajo la aproximación es 1.0696017.
# El error relativo se encuentra dado por 1.1400373.
#
# Resultados de la iteracion 15.
# La aproximación de la raíz se encuentra dada por -1.2158169.
# El valor de la función bajo la aproximación es 0.92923651.
# El error relativo se encuentra dado por 1.1157025.
#
# Resultados de la iteracion 16.
# La aproximación de la raíz se encuentra dada por -1.2750759.
# El valor de la función bajo la aproximación es 0.58422338.
# El error relativo se encuentra dado por 0.98849558.
#
# Resultados de la iteracion 17.
# La aproximación de la raíz se encuentra dada por -1.3205817.
# El valor de la función bajo la aproximación es 0.16034251.
# El error relativo se encuentra dado por 0.62972919.
#
# Resultados de la iteracion 18.
# La aproximación de la raíz se encuentra dada por -1.333657.
# El valor de la función bajo la aproximación es 0.0084092972.
# El error relativo se encuentra dado por 0.17341776.
#
# Resultados de la iteracion 19.
# La aproximación de la raíz se encuentra dada por -1.3343443.
# El valor de la función bajo la aproximación es 2.0623465e-05.
# El error relativo se encuentra dado por 0.0090965602.
#
# Resultados de la iteracion 20.
# La aproximación de la raíz se encuentra dada por -1.3343459.
# El valor de la función bajo la aproximación es 1.2327916e-10.
# El error relativo se encuentra dado por 2.2308959e-05.
#
# Resultados de la iteracion 21.
# La aproximación de la raíz se encuentra dada por -1.3343459.
# El valor de la función bajo la aproximación es 5.3290705e-15.
# El error relativo se encuentra dado por 1.3335444e-10.
#
# Resultados de la iteracion 22.
# La aproximación de la raíz se encuentra dada por -1.3343459.
# El valor de la función bajo la aproximación es -3.5527137e-15.
# El error relativo se encuentra dado por 5.7731597e-15.
#
# Resultados de la iteracion 23.
# La aproximación de la raíz se encuentra dada por -1.3343459.
# El valor de la función bajo la aproximación es -5.3290705e-15.
# El error relativo se encuentra dado por 3.7747583e-15.
#
# Resultados de la iteracion 24.
# La aproximación de la raíz se encuentra dada por -1.3343459.
# El valor de la función bajo la aproximación es 7.1054274e-15.
# El error relativo se encuentra dado por 5.7731597e-15.
#
# Resultados de la iteracion 25.
# La aproximación de la raíz se encuentra dada por -1.3343459.
# El valor de la función bajo la aproximación es -3.5527137e-15.
# El error relativo se encuentra dado por 7.7715612e-15.
#
# Resultados de la iteracion 26.
# La aproximación de la raíz se encuentra dada por -1.3343459.
# El valor de la función bajo la aproximación es -5.3290705e-15.
# El error relativo se encuentra dado por 3.7747583e-15.
#
# Resultados de la iteracion 27.
# La aproximación de la raíz se encuentra dada por -1.3343459.
# El valor de la función bajo la aproximación es 7.1054274e-15.
# El error relativo se encuentra dado por 5.7731597e-15.

# %% [markdown]
# ## 3.- Función $$f(x)= e^3x − 27x^6 + 27x^4e^x − 9x^2e^2x$$
# considere el punto inicial x0 = 3.5.

# %% [markdown]
# # Procedimiento Función 3

# %%
# Importamos las funciones necesarias que empleara la función objetivo
from numpy import cos, sin, exp, e

# Procedemos a definir e inicializar las condiciones de paro del método
tol = 1.*(10**(-15)) # Obtener un error relativo de 10^(-20)
maxItera = 100 # Realizar máximo 100 iteraciones

# %%
# Definimos la funcion objetivo
def fx(x):
    fx = e**(3*x)-9*x**2*e**(2*x)+27*x**4*e**x-27*x**6
    return fx

# Definimos la primera derivada de la funcion objetivo
def fxp(x):
    fxp = 3*e**(3*x)+(-18*x**2-18*x)*e**(2*x)+(27*x**4+108*x**3)*e**x-162*x**5
    return fxp

# Definimos la segunda derivada de la funcion objetivo
def fxpp(x):
    fxpp = 9*e**(3*x)+(-36*x**2-72*x-18)*e**(2*x)+(27*x**4+216*x**3+324*x**2)*e**x-810*x**4
    return fxpp

# %%
# Definimos el punto inicial donde comenzaremos por aplicar el método así como el indice de conteo de las
# iteraciones y un error grande a fin de inicializar el método
p0 = 3.2 # aproximación inicial
k = 0 # Inicilizamos las iteraciones
error = 10000 # Inicializamos el valor del error en un número muy grande
pAnterior = p0 # Inicializamos la primer aproximación como b

# %%
# Definimos una funcion que defina el método iterativo del punto fijo
def itenewtonmultiple(a, fx, fxp, fxpp):
    # Evaluamos para validar si ya tenemos la raíz
    evalua = fx(a)
    # Validamos si llegamos a las raíz
    if evalua==0:
        return 0, a
    else:
        return 1, a -((fx(a)*fxp(a))/(fxp(a)**2-fx(a)*fxpp(a)))

# %%
# Empezamos el método de newton con los datos dados

# En este caso ya tenemos la raíz deseada
if fx(p0) == 0:
    # Se describe que existe una raíz en el punto dado previamente
    print('Se ha encontrado la raíz de la ecuación, la cual está dado por el punto {0}.'.format(p0))
    
# Dado que no tenemos la raíz aún procedemos a realizar iteraciones
else:
    # Señalamos que iniciamos el proceso iterativo
    print('Iniciamos el proceso iterativo')
    
    # Iniciamos el proceso iterativo
    while (error > tol and k < maxItera):
        
        # Iteramos el proceso
        itera = itenewtonmultiple(p0, fx, fxp, fxpp)
        
        # Validamos los casos obtenidos de la bandera, si esta es 0, se ha determinado la raíz
        if itera[0] == 0:
            # Describimos que hemos determinado el punto fijo y lo imprimimos
            print('La raíz de la ecuación se encuentra en el punto: {0}.'.format(itera[1]))
            k = maxItera
            
        # Validamos los casos obtenidos de la bandera, si esta es 1, no se ha determinado el punto fijo
        else:
            # Incrementamos en 1 las iteraciones realizadas
            k = k + 1
            
            # Imprimimos los resultados obtenidos de la iteracion
            print('Resultados de la iteracion {0}.'.format(k))
            print('La aproximación de la raíz se encuentra dada por {:.8}.'.format(itera[1]))
            print('El valor de la función bajo la aproximación es {:.8}.'.format(fx(itera[1])))
            
            # Actualizamos las variables
            error = abs(p0 - itera[1]) + abs(fx(p0)) # Error de aproximaciones
            p0 = itera[1]
            
            # Imprimimos el error
            print('El error relativo se encuentra dado por {:.8}.\n'.format(error))
# Out:
# Iniciamos el proceso iterativo
# Resultados de la iteracion 1.
# La aproximación de la raíz se encuentra dada por 3.4305635.
# El valor de la función bajo la aproximación es -85.897532.
# El error relativo se encuentra dado por 237.1165.
#
# Resultados de la iteracion 2.
# La aproximación de la raíz se encuentra dada por 3.6410356.
# El valor de la función bajo la aproximación es -4.4118813.
# El error relativo se encuentra dado por 86.108004.
#
# Resultados de la iteracion 3.
# La aproximación de la raíz se encuentra dada por 3.7250531.
# El valor de la función bajo la aproximación es -0.0036970695.
# El error relativo se encuentra dado por 4.4958988.
#
# Resultados de la iteracion 4.
# La aproximación de la raíz se encuentra dada por 3.7330195.
# El valor de la función bajo la aproximación es -1.6007107e-09.
# El error relativo se encuentra dado por 0.011663457.
#
# Resultados de la iteracion 5.
# La aproximación de la raíz se encuentra dada por 3.733086.
# El valor de la función bajo la aproximación es -5.8207661e-11.
# El error relativo se encuentra dado por 6.658019e-05.
#
# Resultados de la iteracion 6.
# La aproximación de la raíz se encuentra dada por 3.7330893.
# El valor de la función bajo la aproximación es 0.0.
# El error relativo se encuentra dado por 3.2947951e-06.
#
# La raíz de la ecuación se encuentra en el punto: 3.7330893441511357.

# %% [markdown]
# # Resultados
#
# En la primera función tenemos 30 iteraciones. Donde podemos encontrar la raíz de la ecuación que se encuentra en el punto: $0.7390851334759542.$ y su error relativo es de $1.3031547e-10.$
#
# En la segunda fución tenemos 27 iteraciones. Donde podemos encontrar la aproximación de la raíz en: $-1.3343459$. Con un error relativo de $5.7731597e-15$.
#
# En la tercera función tenemos 6 iteraciones. Donde podemos encontrar el punto de la ecuación en: $3.7330893441511357$. Con un error relativo de $3.2947951e-06$

# %% [markdown]
# # ¿Qué aprendi?
# En la tarea 4 aprendí como utilizar el metodo de newton para obtener puntos fijos de una forma muy rapida pero poco precisa. Con este metodo es mas sencillo encontrar un punto, sin embargo su desventaja es que el error puede llegar a ser muy grande en comparación a otros metodos similares.
#
# Con los ejemplos de la tarea y la clase, el concepto del metodo de newton me quedó muy claro.
