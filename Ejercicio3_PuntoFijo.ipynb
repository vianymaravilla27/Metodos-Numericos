# %% [markdown]
# # Ejercicio3_Método del punto fijo
#
# Considere la función $f(x)=e^{-x}+x-2$, a partir de esta analice la ecuación f(x) = 0, determine la raíz por medio del m étodo del punto fijo, se deberá de especificar la adaptación realizada así como la función empleada en el método del punto fijo.
#
#
# ### Procedimiento:
# #### Condiciones
#
# Para poder aplicar el método del punto fijo a la ecuación debemos garantizar que se cumple:
#
# $$Definimos: $$
# $$-1≤g'(x)≤1   , donde,   $$
#
# $$f(x)=e^{-x}+x-2 ⇒ e^{-x}+x-2=0 ⇒  2 - e ^{-x}$$
# - Determinamos:
# $$ \frac{d}{dx} ( 2 - e ^{-x}) = e^{-x}$$
# - Y por lo tanto:
# $$x ≥ 0$$
#
# Dado lo anterior y observando la gráfico tomamos un punto para empezar el proceso iterativo que se aproxime.
# P0 = 1.8
#
# #### Proceso iterativo
#
# El proceso iterativo se obtiene al seleccionar una aproximación inicial de la raíz $p_0$ y posteriormente generar la sucesión de aproximaciones $p_1 = f(p_0)$ y de esta forma se obtienen las aproximaciones.
#
#
# #### Condición de paro
#
# Al igual que en los métodos anteriores podemos imponer una condición de paro en función de las aproximaciones sucesivas en términos del error relativo, es decir:
#
# $$\frac{\left | p_{n}-p_{n-1}\right |}{\left | p_{n} \right |}<\varepsilon$$

# %%
# Importaremos las funciones a emplear necesarias para definir la ecuación algebraíca
from numpy import exp
import math 


# Procedemos a definir e inicializar las condiciones de paro del método
tol = 1.*(10**(-10)) # Obtener un error relativo de 10^(-10)
maxItera = 100 # Realizar máximo 100 iteraciones

# %%
# Definimos la funcion objetivo
def fx(x):
    fx = exp(-x)
    return fx

# %%
# Definimos el punto inicial donde comenzaremos por aplicar el método así como el indice de conteo de las
# iteraciones y un error grande a fin de inicializar el método
p0 = 1.8 # aproximación inicial
k = 0 # Inicilizamos las iteraciones
error = 10000 # Inicializamos el valor del error en un número muy grande
pAnterior = p0 # Inicializamos la primer aproximación como b

# %%
# Definimos una funcion que defina el método iterativo del punto fijo
def itepuntofijo(pActual,fx):
    # Generamos la siguiente aproximacion
    pNuevo = fx(pActual)
    # Validamos las condiciones y si llegamos a las raices
    if pNuevo == pActual:
        return 0, pActual
    else:
        return 1, pNuevo

# %%
# Empezamos el método de bisección verificando las diferentes condiciones sobre el intervalo para lo que se
# validan las posibilidades de la existencia de la raíz en el intervalo dado

# En este caso no existe una raíz en el intervalo
if fx(pAnterior) == 0:
    # Se describe que existe una raíz en el punto dado previamente
    print('Se ha encontrado el punto fijo, el cual está dado por el punto {0}.'.format(pAnterior))
    
# Dado que no tenemos el punto fijo procedemos a realizar iteraciones
else:
    # Señalamos que iniciamos el proceso iterativo
    print('Iniciamos el proceso iterativo')
    
    # Iniciamos el proceso iterativo
    while (error > tol and k < maxItera):
        
        # Iteramos el proceso
        itera = itepuntofijo(p0,fx)
        
        # Validamos los casos obtenidos de la bandera, si esta es 0, se ha determinado el punto fijo
        if itera[0] == 0:
            # Describimos que hemos determinado el punto fijo y lo imprimimos
            print('El punto fijo de la función se encuentra en el punto: {0}.'.format(itera[1]))
            
        # Validamos los casos obtenidos de la bandera, si esta es 1, no se ha determinado el punto fijo
        else:
            # Incrementamos en 1 las iteraciones realizadas
            k = k + 1
            
            # Imprimimos los resultados obtenidos de la iteracion
            print('Resultados de la iteracion {0}.'.format(k))
            print('La aproximación del punto fijo se encuentra dada por {0}.'.format(itera[1]))
            print('El valor de la función bajo la aproximación es {0}.'.format(fx(itera[1])))
            
            # Actualizamos las variables
            p0 = itera[1]
            error = abs(fx(p0) - p0) # Error relativo de aproximaciones
            
            # Imprimimos el error
            print('El error relativo se encuentra dado por {0}.\n'.format(error))
# Out:
# Iniciamos el proceso iterativo
# Resultados de la iteracion 1.
# La aproximación del punto fijo se encuentra dada por 0.16529888822158653.
# El valor de la función bajo la aproximación es 0.8476403165157733.
# El error relativo se encuentra dado por 0.6823414282941868.
#
# Resultados de la iteracion 2.
# La aproximación del punto fijo se encuentra dada por 0.8476403165157733.
# El valor de la función bajo la aproximación es 0.42842468678693024.
# El error relativo se encuentra dado por 0.4192156297288431.
#
# Resultados de la iteracion 3.
# La aproximación del punto fijo se encuentra dada por 0.42842468678693024.
# El valor de la función bajo la aproximación es 0.6515346578749606.
# El error relativo se encuentra dado por 0.22310997108803032.
#
# Resultados de la iteracion 4.
# La aproximación del punto fijo se encuentra dada por 0.6515346578749606.
# El valor de la función bajo la aproximación es 0.5212452295387884.
# El error relativo se encuentra dado por 0.13028942833617219.
#
# Resultados de la iteracion 5.
# La aproximación del punto fijo se encuentra dada por 0.5212452295387884.
# El valor de la función bajo la aproximación es 0.5937806941619547.
# El error relativo se encuentra dado por 0.07253546462316629.
#
# Resultados de la iteracion 6.
# La aproximación del punto fijo se encuentra dada por 0.5937806941619547.
# El valor de la función bajo la aproximación es 0.5522354994970198.
# El error relativo se encuentra dado por 0.04154519466493489.
#
# Resultados de la iteracion 7.
# La aproximación del punto fijo se encuentra dada por 0.5522354994970198.
# El valor de la función bajo la aproximación es 0.5756614799371359.
# El error relativo se encuentra dado por 0.023425980440116123.
#
# Resultados de la iteracion 8.
# La aproximación del punto fijo se encuentra dada por 0.5756614799371359.
# El valor de la función bajo la aproximación es 0.5623327739059347.
# El error relativo se encuentra dado por 0.013328706031201176.
#
# Resultados de la iteracion 9.
# La aproximación del punto fijo se encuentra dada por 0.5623327739059347.
# El valor de la función bajo la aproximación es 0.5698781152544772.
# El error relativo se encuentra dado por 0.007545341348542456.
#
# Resultados de la iteracion 10.
# La aproximación del punto fijo se encuentra dada por 0.5698781152544772.
# El valor de la función bajo la aproximación es 0.5655943718245825.
# El error relativo se encuentra dado por 0.004283743429894682.
#
# Resultados de la iteracion 11.
# La aproximación del punto fijo se encuentra dada por 0.5655943718245825.
# El valor de la función bajo la aproximación es 0.5680224298747344.
# El error relativo se encuentra dado por 0.0024280580501518934.
#
# Resultados de la iteracion 12.
# La aproximación del punto fijo se encuentra dada por 0.5680224298747344.
# El valor de la función bajo la aproximación es 0.5666449114653013.
# El error relativo se encuentra dado por 0.0013775184094331205.
#
# Resultados de la iteracion 13.
# La aproximación del punto fijo se encuentra dada por 0.5666449114653013.
# El valor de la función bajo la aproximación es 0.5674260131299022.
# El error relativo se encuentra dado por 0.0007811016646008806.
#
# Resultados de la iteracion 14.
# La aproximación del punto fijo se encuentra dada por 0.5674260131299022.
# El valor de la función bajo la aproximación es 0.5669829687803739.
# El error relativo se encuentra dado por 0.00044304434952824323.
#
# Resultados de la iteracion 15.
# La aproximación del punto fijo se encuentra dada por 0.5669829687803739.
# El valor de la función bajo la aproximación es 0.5672342230352498.
# El error relativo se encuentra dado por 0.0002512542548759322.
#
# Resultados de la iteracion 16.
# La aproximación del punto fijo se encuentra dada por 0.5672342230352498.
# El valor de la función bajo la aproximación es 0.5670917209260813.
# El error relativo se encuentra dado por 0.00014250210916855188.
#
# Resultados de la iteracion 17.
# La aproximación del punto fijo se encuentra dada por 0.5670917209260813.
# El valor de la función bajo la aproximación es 0.5671725384506023.
# El error relativo se encuentra dado por 8.081752452104851e-05.
#
# Resultados de la iteracion 18.
# La aproximación del punto fijo se encuentra dada por 0.5671725384506023.
# El valor de la función bajo la aproximación es 0.5671267028222544.
# El error relativo se encuentra dado por 4.583562834792332e-05.
#
# Resultados de la iteracion 19.
# La aproximación del punto fijo se encuentra dada por 0.5671267028222544.
# El valor de la función bajo la aproximación es 0.5671526980267799.
# El error relativo se encuentra dado por 2.599520452550852e-05.
#
# Resultados de la iteracion 20.
# La aproximación del punto fijo se encuentra dada por 0.5671526980267799.
# El valor de la función bajo la aproximación es 0.5671379549680228.
# El error relativo se encuentra dado por 1.474305875714954e-05.
#
# Resultados de la iteracion 21.
# La aproximación del punto fijo se encuentra dada por 0.5671379549680228.
# El valor de la función bajo la aproximación es 0.5671463163778525.
# El error relativo se encuentra dado por 8.361409829737987e-06.
#
# Resultados de la iteracion 22.
# La aproximación del punto fijo se encuentra dada por 0.5671463163778525.
# El valor de la función bajo la aproximación es 0.5671415742548933.
# El error relativo se encuentra dado por 4.742122959200401e-06.
#
# Resultados de la iteracion 23.
# La aproximación del punto fijo se encuentra dada por 0.5671415742548933.
# El valor de la función bajo la aproximación es 0.5671442637163505.
# El error relativo se encuentra dado por 2.689461457205944e-06.
#
# Resultados de la iteracion 24.
# La aproximación del punto fijo se encuentra dada por 0.5671442637163505.
# El valor de la función bajo la aproximación es 0.5671427384057637.
# El error relativo se encuentra dado por 1.5253105868362482e-06.
#
# Resultados de la iteracion 25.
# La aproximación del punto fijo se encuentra dada por 0.5671427384057637.
# El valor de la función bajo la aproximación es 0.5671436034752466.
# El error relativo se encuentra dado por 8.650694829359651e-07.
#
# Resultados de la iteracion 26.
# La aproximación del punto fijo se encuentra dada por 0.5671436034752466.
# El valor de la función bajo la aproximación es 0.567143112856835.
# El error relativo se encuentra dado por 4.906184115638368e-07.
#
# Resultados de la iteracion 27.
# La aproximación del punto fijo se encuentra dada por 0.567143112856835.
# El valor de la función bajo la aproximación es 0.5671433911077565.
# El error relativo se encuentra dado por 2.7825092141497976e-07.
#
# Resultados de la iteracion 28.
# La aproximación del punto fijo se encuentra dada por 0.5671433911077565.
# El valor de la función bajo la aproximación es 0.5671432332996073.
# El error relativo se encuentra dado por 1.578081492148442e-07.
#
# Resultados de la iteracion 29.
# La aproximación del punto fijo se encuentra dada por 0.5671432332996073.
# El valor de la función bajo la aproximación es 0.5671433227994382.
# El error relativo se encuentra dado por 8.949983099082459e-08.
#
# Resultados de la iteracion 30.
# La aproximación del punto fijo se encuentra dada por 0.5671433227994382.
# El valor de la función bajo la aproximación es 0.567143272040209.
# El error relativo se encuentra dado por 5.0759229264230044e-08.
#
# Resultados de la iteracion 31.
# La aproximación del punto fijo se encuentra dada por 0.567143272040209.
# El valor de la función bajo la aproximación es 0.5671433008279652.
# El error relativo se encuentra dado por 2.878775617887186e-08.
#
# Resultados de la iteracion 32.
# La aproximación del punto fijo se encuentra dada por 0.5671433008279652.
# El valor de la función bajo la aproximación es 0.5671432845011823.
# El error relativo se encuentra dado por 1.632678281460187e-08.
#
# Resultados de la iteracion 33.
# La aproximación del punto fijo se encuentra dada por 0.5671432845011823.
# El valor de la función bajo la aproximación es 0.5671432937608076.
# El error relativo se encuentra dado por 9.259625288748907e-09.
#
# Resultados de la iteracion 34.
# La aproximación del punto fijo se encuentra dada por 0.5671432937608076.
# El valor de la función bajo la aproximación es 0.5671432885092732.
# El error relativo se encuentra dado por 5.251534429540072e-09.
#
# Resultados de la iteracion 35.
# La aproximación del punto fijo se encuentra dada por 0.5671432885092732.
# El valor de la función bajo la aproximación es 0.5671432914876458.
# El error relativo se encuentra dado por 2.9783725485899026e-09.
#
# Resultados de la iteracion 36.
# La aproximación del punto fijo se encuentra dada por 0.5671432914876458.
# El valor de la función bajo la aproximación es 0.5671432897984817.
# El error relativo se encuentra dado por 1.6891640308713818e-09.
#
# Resultados de la iteracion 37.
# La aproximación del punto fijo se encuentra dada por 0.5671432897984817.
# El valor de la función bajo la aproximación es 0.5671432907564797.
# El error relativo se encuentra dado por 9.579980142504496e-10.
#
# Resultados de la iteracion 38.
# La aproximación del punto fijo se encuentra dada por 0.5671432907564797.
# El valor de la función bajo la aproximación es 0.5671432902131577.
# El error relativo se encuentra dado por 5.433220540140837e-10.
#
# Resultados de la iteracion 39.
# La aproximación del punto fijo se encuentra dada por 0.5671432902131577.
# El valor de la función bajo la aproximación es 0.5671432905212991.
# El error relativo se encuentra dado por 3.0814140128399004e-10.
#
# Resultados de la iteracion 40.
# La aproximación del punto fijo se encuentra dada por 0.5671432905212991.
# El valor de la función bajo la aproximación es 0.5671432903465388.
# El error relativo se encuentra dado por 1.7476031732854835e-10.
#
# Resultados de la iteracion 41.
# La aproximación del punto fijo se encuentra dada por 0.5671432903465388.
# El valor de la función bajo la aproximación es 0.5671432904456529.
# El error relativo se encuentra dado por 9.911416132268869e-11.
